# %%
import pandas as pd

# %%
Customer_behavior = pd.read_csv('customer_segmentation_mixed.csv')

# %%
Customer_behavior.head()
# Out:
#    Age  Annual_Income  Spending_Score  Monthly_Visits  Gender  \
# 0   56          26102              85               6  Female
# 1   46          70336              75              18    Male
# 2   32         105314              36              10    Male
# 3   60          46641              99               5  Female
# 4   25          54584              19              10    Male
#
#   Preferred_Product
# 0          Clothing
# 1              Home
# 2         Groceries
# 3       Electronics
# 4       Electronics
